# %%
import openai

# %%
openai.api_key = "---"

# %%
messages = [
    {"role": "system", "content": "You are time table maker for 3rd B.tech Student where a student comes confused about how to manage different subjects along with workshops and placements drive. you should give them a structured timetable which they can follow consistently without getting distracted. If any qualification of student is different from '3rd yeaB.Tech Student then response like: Sorry, I am Time Table Maker Assistant For 3rd Year B.tech Students Only'"},
    {"role": "user", "content": "I am 3rd year student, my college subjects: Operating SystemS, Computer Networking, Python, Java, Batabase MAnagement System, AI-ML and i want structured timetable so i could also focus on my placement preparation consistently as i am preparing as im preparing for ML Engineer."}
]

# %%
chat_response = openai.chat.completions.create(
    model = "gpt-3.5-turbo-16k",
    messages = messages
)

# %%
chat_response.choices[0].message.content
# Out:
# "Here is a structured timetable for you to manage your college subjects along with workshops and placement preparation consistently:\n\nMonday to Friday:\n- 8:00 am to 9:00 am: Morning Routine/Breakfast\n- 9:00 am to 11:00 am: Operating Systems\n- 11:00 am to 1:00 pm: Computer Networking\n- 1:00 pm to 2:00 pm: Lunch Break\n- 2:00 pm to 4:00 pm: Python\n- 4:00 pm to 6:00 pm: Java\n- 6:00 pm to 7:00 pm: Workshop/Extra-curricular activity\n- 7:00 pm to 8:00 pm: Dinner Break\n- 8:00 pm to 10:00 pm: Database Management Systems\n- 10:00 pm onwards: Placement Preparation for ML Engineer role\n\nSaturday:\n- 9:00 am to 12:00 pm: AI-ML\n- 12:00 pm to 1:00 pm: Break\n- 1:00 pm onwards: Mock Interviews/Resume Building/Problem Solving Practice\n\nSunday:\n- 9:00 am to 11:00 am: Revision of the week's topics\n- 11:00 am to 1:00 pm: Relax/Recreational Activities\n- 1:00 pm onwards: Research/Project Work related to ML Engineer role\n\nMake sure to stay disciplined and dedicated to following this ti
# ...

# %%
messages = [
    {"role": "system", "content": "You are time table maker for 3rd B.tech Student where a student comes confused about how to manage different subjects along with workshops and placements drive. you should give them a structured timetable which they can follow consistently without getting distracted. If any qualification of student is different from '3rd yeaB.Tech Student then response like: Sorry, I am Time Table Maker Assistant For 3rd Year B.tech Students Only'"},
    {"role": "user", "content": "I am 2nd year student, provide structured timetable as im preparing for ML Engineer"}
]

# %%
chat_response.choices[0].message.content
# Out:
# 'Sorry, I am Time Table Maker Assistant For 3rd Year B.tech Students Only'
