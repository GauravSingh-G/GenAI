# %%
import openai

# %%
openai.api_key = "---"

# %%
r1 = "The Ambience of the restaurant was good but the food was pathetic which spoiled my whole experience"
r2 = "The food and the place was amazing. Will definitely come here next time!!"
r3 = "The Paneer dish was neither too good nor too bad. It's a one time experience"

# %%
messages = [
    {"role":"system", "content":"You are Review/Rating anayzer, Check whether the review is Good, Bad or Okay related to Zomato/Swiggy contexts"},
    {"role":"user", "content": r1}
]

# %%
chat_response = openai.chat.completions.create(
    model = "gpt-3.5-turbo-16k",
    messages = messages
)

# %%
chat_response.choices[0].message.content
# Out:
# 'The review is Bad. The customer had a negative experience with the food quality despite good ambience.'

# %%
messages = [
    {"role":"system", "content":"You are Review/Rating anayzer, Check whether the review is Good, Bad or Okay related to Zomato/Swiggy contexts"},
    {"role":"user", "content": r2}
]

# %%
chat_response.choices[0].message.content
# Out:
# 'Good'

# %%
messages = [
    {"role":"system", "content":"You are Review/Rating anayzer, Check whether the review is Good, Bad or Okay related to Zomato/Swiggy contexts"},
    {"role":"user", "content": r3}
]

# %%
chat_response.choices[0].message.content
# Out:
# 'Okay'
