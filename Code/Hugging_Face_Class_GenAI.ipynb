# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
classifier(["I am Happy", "Movie was Bad", "That Person is so Angry"])
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998801946640015},
#  {'label': 'NEGATIVE', 'score': 0.9997554421424866},
#  {'label': 'NEGATIVE', 'score': 0.9983444213867188}]

# %%
zero_shot = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]

# %%
zero_shot("India won 2 gold medals in Olympics", candidate_labels = ['education', 'sports', 'business'])
# Out:
# {'sequence': 'India won 2 gold medals in Olympics',
#  'labels': ['sports', 'business', 'education'],
#  'scores': [0.9850531220436096, 0.009418344125151634, 0.00552857480943203]}

# %%
generator = pipeline('text-generation')
# Out:
# No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]

# %%
ner = pipeline("ner")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
ner("I am Gaurav Singh and pursuing B.tech from Hindustan College of Science of Technology situated in Farah, Mathura")
# Out:
# [{'entity': 'I-PER',
#   'score': np.float32(0.9993224),
#   'index': 3,
#   'word': 'G',
#   'start': 5,
#   'end': 6},
#  {'entity': 'I-PER',
#   'score': np.float32(0.99708825),
#   'index': 4,
#   'word': '##au',
#   'start': 6,
#   'end': 8},
#  {'entity': 'I-PER',
#   'score': np.float32(0.95840716),
#   'index': 5,
#   'word': '##ra',
#   'start': 8,
#   'end': 10},
#  {'entity': 'I-PER',
#   'score': np.float32(0.99673814),
#   'index': 6,
#   'word': '##v',
#   'start': 10,
#   'end': 11},
#  {'entity': 'I-PER',
#   'score': np.float32(0.99925023),
#   'index': 7,
#   'word': 'Singh',
#   'start': 12,
#   'end': 17},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.99617684),
#   'index': 14,
#   'word': 'Hindus',
#   'start': 43,
#   'end': 49},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.9900893),
#   'index': 15,
#   'word': '##tan',
#   'start': 49,
#   'end': 52},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.96489775),
#   'index': 16,
#   'word': 'College',
# ...

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="google/flan-t5-base")

question = "What is the capital of India?"
context = "India is a country in Asia. Its capital is New Delhi."

prompt = f"Answer the question based on context:\nContext: {context}\nQuestion: {question}"

result = pipe(prompt)

print(result)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# ...

# %%
from transformers import pipeline

pipe = pipeline(
    "document-question-answering",
    model="ahotrod/electra_large_discriminator_squad2_512"
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# The model 'ElectraForQuestionAnswering' is not supported for document-question-answering. Supported models are ['PeftModelForQuestionAnswering', 'LayoutLMForQuestionAnswering', 'LayoutLMv2ForQuestionAnswering', 'LayoutLMv3ForQuestionAnswering'].

# %%
import os
os.environ['HF_TOKEN']='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'
